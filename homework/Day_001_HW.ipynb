# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = sum((y - yp)**2) / len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 170.213
# The Mean absolute error is 10.198

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
# 我在Dataset中找了一組有關於審計的數據資料，如網址:https://www.kaggle.com/sid321axn/audit-data ，會選關於審計方面的資料主要有以下幾點，第一，屬於企業業務面向，因為目前正在公司中擔任財務部的內部控制實習生，因此想要研究如何透過數聚的分析，來提升內部控制的效率，與分析深度。第二，屬於保護利害關係人面向，近期可以看到不少財務造假的公司，如瑞幸咖啡、Theranos等等，卻在很晚才發現這樣的騙局，希望透過分析財務數據資料，預測公司可能的風險，提前避免詐欺案件。第三，屬於未來趨勢面向，據我所知，目前台灣的審計工作大多鮮少借用數據分析的工具來進行，因此覺得有蠻不錯的發展潛力。但因審計的數據基本上屬與公司機密，kaggle上很少使用內部資訊來分析的案例，因此想先透過這個簡單的數據來得到靈感，在用我工作上的數據來嘗試。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 此筆資料來自於UCI Machine Learning repository。基本上是來自印度的審計公司，其同時為印度政府的外部審計公司，利用比對歷史的風險係數來分析現況。
#
# 3. 蒐集而來的資料型態為何
#
# 結構性資料 : 數值
#
# 4. 這組資料想解決的問題如何評估
#
# 透過風險指數來評估。
# 此筆數據只是審計作業中的其中一環，因此我們無法從頭到尾了解其如何使用此筆數據，在kaggle上也並未解釋其如何評估其成效。我想他只是想做初步的分類，幫助其做進一步的分析，所以我想只要能減輕他門的工作負擔，即表示成效還不錯。
#
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 以天數為基準單位，提升每天的載客量或載客里程數，以提升業績。我們可能會想知道不同時間點，不同地點的需求密度，同時也要知道供給密度。因為若是需求密度高，但是供給密度也高，大家都在搶生意反而效果不彰。反之，如果需求密度雖然不高，但是供給密度即低，那麼該時該地就有值得前往的意義。另外，總不可能一昧地追求密度比，雖然第一趟有生意，但是卻要跑很遠的距離到下個地方接生意，所以也要懂得規劃路線，好讓一整天的供需密度比不會落差太大，使得整體效益最大。而最終目標希望可以建立一套載客機器人，來建議司機下一站要前往何處載客。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 依據經驗實地探訪可能的熱門乘車點，例如觀光景點、飯店、捷運站、高級住宅區、科技園區、商圈、辦公大樓林立區等等，在不同地方的不同時間點紀錄，每一小時有多少客人需要搭車，同時也記錄有多少計程車在等待，紀錄每小時有多少計程車載到乘客而出發。另外，同時也要記錄當日的天氣、氣溫、是否為重要節日或假日，可以的話司機也可以藉由聊天來記錄乘客搭乘目的，是否為常客還是鮮少搭乘。
#
# 3. 蒐集而來的資料型態為何
#
# 結構性資料 : 數值、字串
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# 透過每天的總載客次數、每天載客總行程里數
